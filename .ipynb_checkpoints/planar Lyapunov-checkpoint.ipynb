# %% [markdown]
# В данном ноутбуке можно посчитать семейство орбит Ляпунова для заданной системы. Сохранить посчитанные данные в файл.
# Для отдельно взятой орбиты возможно нарисовать устойчивое и неустойчивое многообразие

# %%
import numpy as np
from scipy import optimize, interpolate
import scipy
import os

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

from crtbp_planar_prop import propCrtbp, prop2Limits, findVLimits,findVLimits_debug
# ОСТОРОЖНО! findVLimits_debug сохраняет кучу картинок
from lagrange_pts import lagrange1, lagrange2
from stop_funcs import stopFunCombined, iVarX, iVarY, iVarAlpha, iVarAlphaPi

# %matplotlib inline

# %%
# omega and jacobi for planar problem
def omega(y):
    r1 = np.sqrt((y[:,0] + mu2)**2 + y[:,1]**2 )
    r2 = np.sqrt((y[:,0] - 1 + mu2)**2 + y[:,1]**2 )
    return 0.5*(y[:,0]**2 + y[:,1]**2) + (1 - mu2) / r1 + mu2 / r2
    
def jacobi_const(y):
    return 2*omega(y) - y[:,2]**2 - y[:,3]**2

# %%
# префикс для имен файлов (для сохраняемых картинок и прочего)
NAME = 'EML2 '

# %%
Sm =  1.9891e30 # mass of the Sun
Em =  5.97e24 # mass of the Earth
Mm =  7.34767e22 # mass of the Moon
ER =  1.496e8 # Sun-Earth distance
ME =  384400
#mu2 = Em / (Sm + Em) # CRTBP main coefficient

mu2 = 0.0121505856  # Mm/(Em+Mm)

mu1 = 1-mu2

L = [lagrange1(mu2), lagrange2(mu2)] # L1, L2 positions


rtol = 1e-12 # integration relative tolerance
nmax = 1e6 # max number of integration steps
int_param = {'atol':rtol, 'rtol':rtol, 'nsteps':nmax}

# %%
plt.scatter([L[0], L[1], 1-mu2], [0, 0, 0])

# %%
# события для EML2
eventA = {'ivar':iVarAlpha, 'stopval': np.deg2rad(160), 'direction':0, 'isterminal':True, 'corr':False, 'kwargs':{'center':mu1+10/ME}}
eventB = {'ivar':iVarAlpha, 'stopval': np.deg2rad(-160), 'direction':0, 'isterminal':True, 'corr':False, 'kwargs':{'center':mu1+10/ME}}
eventR = {'ivar':iVarX, 'stopval':   L[1]+150000/ME, 'direction':0, 'isterminal':True,  'corr':False}
eventL = {'ivar':iVarX, 'stopval':   L[0]-150000/ME, 'direction':0, 'isterminal':True,  'corr':False}
eventY = {'ivar':iVarY, 'stopval':   -0.8, 'direction':0, 'isterminal':True,  'corr':False}
eventYUP = {'ivar':iVarY, 'stopval':   0.8, 'direction':0, 'isterminal':True,  'corr':False}
eventYcross = {'ivar':iVarY, 'stopval':   0, 'direction': 0, 'isterminal':False,  'corr':True}
eventYStopL2 = {'ivar':iVarY, 'stopval':   0, 'direction': 1, 'isterminal':True,  'corr':True}
lims = {'left':[eventA, eventB], 'right':[eventR, eventY]}

# %%
# события для EML1
eventAL1 = {'ivar':iVarAlphaPi, 'stopval': np.deg2rad(45), 'direction':0, 'isterminal':True, 'corr':False, 'kwargs':{'center':mu1-10/ME}}
eventBL1 = {'ivar':iVarAlphaPi, 'stopval': np.deg2rad(-45)+2*np.pi, 'direction':0, 'isterminal':True, 'corr':False, 'kwargs':{'center':mu1-10/ME}}
eventRL1 = {'ivar':iVarX, 'stopval':   mu1 - 20000/ME, 'direction':0, 'isterminal':True,  'corr':False}
eventLL1 = {'ivar':iVarX, 'stopval':   L[0]-90000/ME, 'direction':0, 'isterminal':True,  'corr':False}
eventY = {'ivar':iVarY, 'stopval':   -0.8, 'direction':0, 'isterminal':True,  'corr':False}
eventYUP = {'ivar':iVarY, 'stopval':   0.8, 'direction':0, 'isterminal':True,  'corr':False}
eventYcross = {'ivar':iVarY, 'stopval':   0, 'direction': 0, 'isterminal':False,  'corr':True}
eventYStopL1 = {'ivar':iVarY, 'stopval':   0, 'direction': -1, 'isterminal':True,  'corr':True}
#lims = {'left':[eventA, eventB], 'right':[eventR, eventY]}
#limsL1 = {'right':[eventRL1], 'left':[eventLL1, eventY]}
limsL1 = {'right':[eventAL1, eventBL1,eventY], 'left':[eventLL1 ]}

# %% [markdown]
# Если ранее для выбранной системы уже было посчитано семейство орбит Ляпунова, то выполнить следующие две ячейки
# Возможно, надо будет изменить номер загружаемого файла

# %%
files = [f for f in os.listdir('.') if f.endswith('.txt') and f.startswith(NAME)]
files
# Out:
# ['EML2 lyapunov + jc.txt',
#  'EML2 lyapunov N = 51 + jc.txt',
#  'EML2 lyapunov N = 51.txt']

# %%
xy = np.loadtxt(files[0], dtype=np.float64, delimiter='\t')

# %% [markdown]
# поиск начальных условия для орбит ляпунова
# очень маленькие (близкие к l2) не считаются, думаю, что нужно точнее регулировать ограничения, особенно левое

# %%
xy[:,0]
# Out:
# array([ 1.1557  ,  1.152586,  1.149472,  1.146358,  1.143244,  1.14013 ,
#         1.137016,  1.133902,  1.130788,  1.127674,  1.12456 ,  1.121446,
#         1.118332,  1.115218,  1.112104,  1.10899 ,  1.105876,  1.102762,
#         1.099648,  1.096534,  1.09342 ,  1.090306,  1.087192,  1.084078,
#         1.080964,  1.07785 ,  1.074736,  1.071622,  1.068508,  1.065394,
#         1.06228 ,  1.059166,  1.056052,  1.052938,  1.049824,  1.04671 ,
#         1.043596,  1.040482,  1.037368,  1.034254,  1.03114 ,  1.028026,
#         1.024912,  1.021798,  1.018684,  1.01557 ,  1.012456,  1.009342,
#         1.006228,  1.003114,  1.      ])

# %%
1 - mu2
# Out:
# 0.9878494144

# %%
# Для L2
lst = []
N = 13
x0 = np.linspace(1., 0.988, N)
y0 = np.array([x0[0], 0, 0, 1.41781160e+00])
y0[2:4] += findVLimits(mu1, y0, 90, lims, 0.1, int_param=int_param)
print(y0)
lst.append(y0)
for x in x0[1:]:
    if len(lst) > 2:
        f = interpolate.interp1d([lst[-1][0], lst[-2][0]], [lst[-1][3], lst[-2][3]], fill_value='extrapolate' )
        y0 = np.array([x, 0, 0, f(x)])
    else:
        y0 = np.array([x, 0, 0, lst[-1][3]])
    y0[2:4] += findVLimits(mu1, y0, 90, lims, 0.1, int_param=int_param)
    lst.append(y0)
    print(y0)
# Out:
# 60
# [  1.00000000e+00   0.00000000e+00   1.44780657e-25   1.41781160e+00]
# 72
# [  9.99000000e-01   0.00000000e+00   3.86654059e-18   1.48095700e+00]
# 86
# [  9.98000000e-01   0.00000000e+00   4.41300887e-18   1.55302691e+00]
# 82
# [  9.97000000e-01   0.00000000e+00   6.92321972e-19   1.63640329e+00]
# 73
# [  9.96000000e-01   0.00000000e+00   8.99077774e-19   1.73446272e+00]
# 75
# [  9.95000000e-01   0.00000000e+00   1.20388701e-18   1.85218312e+00]
# 67
# [  9.94000000e-01   0.00000000e+00   1.67598082e-18   1.99727437e+00]
# 76
# [  9.93000000e-01   0.00000000e+00   2.45556078e-18   2.18246796e+00]
# 79
# [  9.92000000e-01   0.00000000e+00   3.85969878e-18   2.43069522e+00]
# 200
# [  9.91000000e-01   0.00000000e+00  -3.99242069e-16  -3.84119530e+00]
# 200
# [  9.90000000e-01   0.00000000e+00  -1.23077003e-15  -3.02130858e+01]
# 200
# [  9.89000000e-01   0.00000000e+00  -1.23077003e-15  -7.66849763e+01]
# 200
# [  9.88000000e-01   0.00000000e+00  -1.23077003e-15  -1.43256867e+02]

# %%
# Для L1
lst = []
N = 51
x0 = np.linspace(L[0] + 450/ME, L[0] + 50000/ME, N)
y0 = np.array([x0[0], 0, 0, 0])
y0[2:4] += findVLimits_debug(mu1, y0, 90, limsL1, 0.1, int_param=int_param)
ind = 0
print(ind, y0)
lst.append(y0)
for x in x0[1:]:
    if len(lst) > 2:
        f = interpolate.interp1d([lst[-1][0], lst[-2][0]], [lst[-1][3], lst[-2][3]], fill_value='extrapolate' )
        y0 = np.array([x, 0, 0, f(x)])
    else:
        y0 = np.array([x, 0, 0, lst[-1][3]])
    y0[2:4] += findVLimits_debug(mu1, y0, 90, limsL1, 0.1, int_param=int_param)
    lst.append(y0)
    ind += 1
    print(ind, y0)
# Out:
# 0 [  8.38148633e-01   0.00000000e+00  -6.26685130e-19  -1.02345449e-02]
# 1 [  8.40726677e-01   0.00000000e+00  -1.27478742e-18  -3.10534033e-02]
# 2 [  8.43304721e-01   0.00000000e+00  -1.23107931e-18  -5.11584541e-02]
# 3 [  8.45882764e-01   0.00000000e+00   3.96266756e-20  -7.06163523e-02]
# 4 [  8.48460808e-01   0.00000000e+00   3.59019097e-20  -8.94879277e-02]
# 5 [  8.51038852e-01   0.00000000e+00   3.25133172e-20  -1.07828520e-01]
# 6 [  8.53616895e-01   0.00000000e+00   2.94288004e-20  -1.25688504e-01]
# 7 [  8.56194939e-01   0.00000000e+00   2.66127843e-20  -1.43113868e-01]
# 8 [  8.58772983e-01   0.00000000e+00   2.40302034e-20  -1.60146790e-01]
# 9 [  8.61351027e-01   0.00000000e+00   2.16482918e-20  -1.76826167e-01]
# 10 [  8.63929070e-01   0.00000000e+00   1.94372252e-20  -1.93188111e-01]
# 11 [  8.66507114e-01   0.00000000e+00   1.73701800e-20  -2.09266378e-01]
# 12 [  8.69085158e-01   0.00000000e+00   1.54231107e-20  -2.25092767e-01]
# 13 [  8.71663201e-01   0.00000000e+00   1.35744056e-20  -2.40697469e-01]
# 14 [  8.74241245e-01   0.00000000e+00   1.18045020e-20  -2.56109388e-01]
# 15 [  8.76819289e-01   0.00000000e+00   1.00955010e-20  -2.71356436e-01]
# 16 [  8.79397333e-01   0.00000000e+00   8.43079778e-21  -2.86465798e-01]
# 17 [  8.81975376e-01   0.00000000e+00   6.79473294e-21  -3.01464194e-01]
# 18 [  8.84553420e-01   0.00000000e+00   5.17226162e-21  -3.16378120e-01]
# 19 [  8.87131464e-01   0.00000000e+00   3.54863541e-21  -3.31234093e-01]
# 20 [  8.89709507e-01   0.00000000e+00   1.90908900e-21  -3.46058888e-01]
# 21 [  8.92287551e-01   0.00000000e+00   2.38522204e-22  -3.60879788e-01]
# 22 [  8.94865595e-01   0.00000000e+00  -1.47883306e-21  -3.75724838e-01]
# 23 [  8.97443638e-01   0.00000000e+00  -3.25977307e-21  -3.90623125e-01]
# 24 [  9.00021682e-01   0.00000000e+00  -5.12252418e-21  -4.05605069e-01]
# 25 [  9.02599726e-01   0.00000000e+00  -7.08720332e-21  -4.20702756e-01]
# 26 [  9.05177770e-01   0.00000000e+00  -9.17635829e-21  -4.35950304e-01]
# 27 [  9.07755813e-01   0.00000000e+00  -1.14156145e-20  -4.51384284e-01]
# 28 [  9.10333857e-01   0.00000000e+00  -1.38344621e-20  -4.67044197e-01]
# 29 [  9.12911901e-01   0.00000000e+00  -1.64672290e-20  -4.82973040e-01]
# 30 [  9.15489944e-01   0.00000000e+00  -1.93542969e-20  -4.99217964e-01]
# 31 [  9.18067988e-01   0.00000000e+00  -2.25436428e-20  -5.15831052e-01]
# 32 [  9.20646032e-01   0.00000000e+00  -2.60928103e-20  -5.32870269e-01]
# 33 [  9.23224076e-01   0.00000000e+00  -3.00714616e-20  -5.50400590e-01]
# 34 [  9.25802119e-01   0.00000000e+00  -3.45647145e-20  -5.68495396e-01]
# 35 [  9.28380163e-01   0.00000000e+00  -3.96775555e-20  -5.87238185e-01]
# 36 [  9.30958207e-01   0.00000000e+00  -4.55407434e-20  -6.06724711e-01]
# 37 [  9.33536250e-01   0.00000000e+00  -5.23188033e-20  -6.27065668e-01]
# 38 [  9.36114294e-01   0.00000000e+00  -6.02209922e-20  -6.48390108e-01]
# 39 [  9.38692338e-01   0.00000000e+00  -6.95165540e-20  -6.70849840e-01]
# 40 [  9.41270381e-01   0.00000000e+00  -8.05562638e-20  -6.94625155e-01]
# 41 [  9.43848425e-01   0.00000000e+00  -9.38033623e-20  -7.19932396e-01]
# 42 [  9.46426469e-01   0.00000000e+00  -1.09878785e-19  -7.47034093e-01]
# 43 [  9.49004513e-01   0.00000000e+00  -1.29628631e-19  -7.76252787e-01]
# 44 [  9.51582556e-01   0.00000000e+00  -1.54227067e-19  -8.07990200e-01]
# 45 [  9.54160600e-01   0.00000000e+00  -1.85337266e-19  -8.42754400e-01]
# 46 [  9.56738644e-01   0.00000000e+00  -2.25370354e-19  -8.81199177e-01]
# 47 [  9.59316687e-01   0.00000000e+00  -2.77915896e-19  -9.24182665e-01]
# 48 [  9.61894731e-01   0.00000000e+00  -3.48485389e-19  -9.72857351e-01]
# 49 [  9.64472775e-01   0.00000000e+00  -4.45855845e-19  -1.02881342e+00]
# 50 [  9.67050818e-01   0.00000000e+00  -5.84634090e-19  -1.09431728e+00]

# %%
y0
# Out:
# array([ 0.94384843,  0.        ,  0.        , -0.71840047])

# %%
#f = interpolate.interp1d([lst[-1][0], lst[-2][0]], [lst[-1][3], lst[-2][3]], fill_value='extrapolate' )
#x = x0[41]
y0 = np.array([  9.43848425e-01,   0.00000000e+00,  -8.96958105e-20,  -7.19865315e-01])
#y0 = np.array([x, 0, 0, f(x)])
findVLimits_debug(mu1, y0, 90, limsL1, 0.1, int_param=int_param)
# Out:
# array([ -4.10743999e-21,  -6.70795857e-05])

# %%
arr = propCrtbp(mu1, y0, [0, 1000*np.pi], int_param=int_param)
plt.plot(arr[:,0], arr[:,1])
plt.scatter(mu1, 0, s=20)
plt.scatter(L[0], 0, s=20)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\scipy\integrate\_ode.py:1035: UserWarning: dopri5: step size becomes too small
#   self.messages.get(idid, 'Unexpected idid=%s' % idid))

# %%
xy = np.array(lst)
#xy1 = np.array(lst)
#xy = np.vstack((xy, xy1[1:-4]))

# %%
# сохранить посчитанное семейство для следующего раза
#xy = np.array(lst)
#N = 51
xyc = np.hstack((xy, jacobi_const(xy).reshape(-1,1)))
np.savetxt(NAME + 'lyapunov + jc'.format(str(N)) + '.txt', xyc, fmt='%.18e', delimiter='\t', newline='\n')

# %% [markdown]
# для отладки

# %%
#y0 = np.array([ 1.0194625 ,  0.        ,  0.        ,  0.84713697])
y0 = np.array([L[0] + 50000/ME, 0, 0, -1.09431728e+00])
#y0 = np.array([mu1 - 10000/ME, 0, 0, 0])
y0[2:] += findVLimits_debug(mu1, y0, 90, limsL1, 0.1, int_param=int_param)
y0
# Out:
# array([  9.67050818e-01,   0.00000000e+00,  -5.21320786e-26,
#         -1.09431728e+00])

# %%
N = 13
x0 = np.linspace(L[0] + 450/ME, mu1 - 30000/ME, N)
y0 = np.array([x0[12], 0, 0, 0])
y0[2:] += findVLimits_debug(mu1, y0, 90, limsL1, 0.1, int_param=int_param)

# %% [markdown]
# как меняется начальная скорость по y от начального x, и синим нарисована производная

# %%
plt.scatter(xy[1:,0], xy[1:,3]-xy[:-1,3])
plt.scatter(xy[:,0], xy[:,3], color='red')
plt.xlabel('X')
plt.ylabel('VY')

# %% [markdown]
# <h1>Многообразия для одной орбиты Ляпунова</h1>

# %%
# чтобы заново не считать, раскомментировать следущую строку и закомментировать следующую через одну
#y0 = np.array([  1.14013000e+00,   0.00000000e+00,  -1.36423389e-20, 8.05146317e-02])
xy = np.array(lst)
y0 = xy[8, :].copy()
evout = []
arr = propCrtbp(mu1, y0, [0, 5*np.pi], stopf=stopFunCombined, events = [eventYStop], out=evout, int_param=int_param)

# %%
# построение выбранной орбиты
plt.scatter(arr[:,0],arr[:,1], s=0.2)
plt.plot(L[1], 0, '+')
plt.plot(1-mu2, 0, '+')
plt.plot(L[0], 0, '+')
plt.axis('equal')
# Out:
# (0.79881227795368437,
#  1.1727301164112185,
#  -0.10221511911457483,
#  0.10221896320138409)

# %%
# интерполируется орбита, чтобы равномерно были распределены точки по ней 
l = np.cumsum(np.linalg.norm(arr[1:,:2]-arr[:-1,:2], axis=1))
intrp = scipy.interpolate.interp1d(l, arr[1:,:4], axis=0, kind='cubic', copy=False)#, assume_sorted=False)
ls = np.linspace(l[0], l[-1], 50)
orb = intrp(ls)

# %%
# отрисовывается проинтерполированная орбита
plt.scatter(orb[:,0], orb[:,1], s=0.2)
plt.plot(L[1], 0, '+')
plt.plot(1-mu2, 0, '+')
plt.plot(L[0], 0, '+')
plt.axis('equal')
# Out:
# (0.79885176688086756,
#  1.1727282359861146,
#  -0.10215730685197873,
#  0.10218852597330125)

# %%
# расчет многообразий
# по оси x дается импульс постоянный по величине
manifold = []
manifold_stable = []
man_evout = []
for y1 in orb:
    evout = []
    y0 = y1.copy()
    y0[2] += 1e-5 #np.sqrt(y0[2]**2 + y0[3]**2)*1e-5
    
    #arr = propCrtbp(mu1, y0, [0, 4*np.pi],stopf=stopFunCombined, events =\
    #                [eventL, eventR, eventY, eventYUP], out= evout, int_param=int_param)
    arr = propCrtbp(mu1, y0, [0, 1.7*np.pi],int_param=int_param)
    manifold.append(arr)
    #arr = propCrtbp(mu1, y0, [0, -4*np.pi],stopf=stopFunCombined, events =\
    #            [eventL, eventR, eventY, eventYUP], out= evout, int_param=int_param)
    arr = propCrtbp(mu1, y0, [0, -1.3*np.pi],int_param=int_param)
    manifold_stable.append(arr)
    
    y0[2] -= 2e-5 #np.sqrt(y0[2]**2 + y0[3]**2)*1e-5
    
    #arr = propCrtbp(mu1, y0, [0, 4*np.pi],stopf=stopFunCombined, events =\
    #            [eventL, eventR, eventY, eventYUP], out= evout, int_param=int_param)
    arr = propCrtbp(mu1, y0, [0, 1.3*np.pi],int_param=int_param)
    manifold.append(arr)
    #arr = propCrtbp(mu1, y0, [0, -4*np.pi],stopf=stopFunCombined, events =\
    #            [eventL, eventR, eventY, eventYUP], out= evout, int_param=int_param)
    arr = propCrtbp(mu1, y0, [0, -1.7*np.pi],int_param=int_param)
    manifold_stable.append(arr)

# %%
# отрисовка многообразий, устойчивое и не устойчивое на разных графиках
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

for y in manifold:
    ax1.plot(y[:,0], y[:,1], 'r', alpha=0.3)
    
for y in manifold_stable:
    ax2.plot(y[:,0], y[:,1], 'b', alpha=0.3)

ax1.scatter(L[1], 0, s=20, c='blue')
ax1.scatter(1-mu2, 0, s=30, c='k')
ax1.scatter(L[0], 0, s=20, c='blue')
ax1.axis('equal')   

ax2.scatter(L[1], 0, s=20, c='r')
ax2.scatter(1-mu2, 0, s=30, c='k')
ax2.scatter(L[0], 0, s=20, c='r')
ax2.axis('equal')  
    
#fig = plt.gcf()
f.set_size_inches(20.5, 10.5)
f.savefig(NAME+'manifolds 2.png', dpi=300)

# %%
# отрисовка многообразий, устойчивое и не устойчивое на одном графике
for i in range(len(manifold)):
    plt.plot(manifold[i][:,0], manifold[i][:,1], 'r', alpha=0.3)
    plt.plot(manifold_stable[i][:,0], manifold_stable[i][:,1], 'b', alpha=0.3)

plt.scatter(L[1], 0, s=20, c='blue')
plt.scatter(1-mu2, 0, s=30, c='k')
plt.scatter(L[0], 0, s=20, c='blue')
plt.axis('equal')    
    
fig = plt.gcf()
fig.set_size_inches(8.5, 10.5)
fig.savefig(NAME+'manifolds.png', dpi=300)

# %%
# Out:
# array([  1.00000000e+00,   0.00000000e+00,   2.47218596e-18,
#          1.41781160e+00])

# %%
arr[:,0] = (arr[:,0]-L[1])*ME

# %%
arr[:,1] *= ME

# %%
arr_pos = arr[arr[:,1]>0, :]

# %%
plt.plot(arr_pos[:,0], arr_pos[:,1])

# %%
xy[50,:]
# Out:
# array([  1.00000000e+00,   0.00000000e+00,   2.47218596e-18,
#          1.41781160e+00])

# %%
jc = jacobi_const(xy)
plt.scatter(xy[:, 0], jc)
plt.xlabel('X')
plt.ylabel('Jacobi const')

# %%
jc
# Out:
# array([ 3.17216045,  3.17195607,  3.17136435,  3.17042051,  3.16915495,
#         3.16759409,  3.16576109,  3.1636764 ,  3.16135817,  3.15882263,
#         3.15608434,  3.15315643,  3.1500508 ,  3.14677828,  3.14334874,
#         3.1397712 ,  3.13605394,  3.13220456,  3.12823004,  3.1241368 ,
#         3.11993073,  3.11561725,  3.1112013 ,  3.10668738,  3.10207958,
#         3.09738152,  3.09259645,  3.08772714,  3.08277594,  3.0777447 ,
#         3.07263478,  3.06744697,  3.06218143,  3.05683764,  3.05141425,
#         3.04590897,  3.04031838,  3.0346377 ,  3.02886049,  3.02297818,
#         3.01697955,  3.01084988,  3.00456978,  2.99811345,  2.99144605,
#         2.98451945,  2.97726525,  2.96958249,  2.96131486,  2.95220472,
#         2.94179138])

# %% [markdown]
# <h2>   Сделать гифку из посчитанных орбит</h2>

# %%
xy1 = np.array(lst)

# %%
def animate(i):
    evout = []
    arr = propCrtbp(mu1, xyc[i, :-1], [0, 7*np.pi], stopf=stopFunCombined,\
                    events = [eventYStopL1], out=evout, int_param=int_param)
    line.set_xdata(arr[:,0])
    line.set_ydata(arr[:,1])
    ax.set_title('Jacobi const = ' + str(round(xyc[i,4],3)))
    
fig, ax = plt.subplots(figsize=(5, 10))
ax.set(xlim=(0.3, 1.3), ylim=(-1, 1), xlabel='X', ylabel='Y')
ax.set_aspect('equal')
ax.scatter(L[0], 0, s=20, c='r')
ax.scatter(L[1], 0, s=20, c='r')
ax.scatter(1 - mu2, 0, s=20, c='k')
line = ax.plot(0, 0, lw=1)[0]


anim = FuncAnimation(fig, animate, interval=100, frames=xyc.shape[0])
anim.save('lyapunov family L1.gif',  writer='imagemagick', dpi=200)

# %%
evout = []
arr = propCrtbp(mu1, y0, [0, 5*np.pi], stopf=stopFunCombined, events = [eventYStop], out=evout, int_param=int_param)

# %%
# построение выбранной орбиты
plt.scatter(arr[:,0],arr[:,1], s=0.2)
plt.plot(L[1], 0, '+')
plt.plot(1-mu2, 0, '+')
plt.plot(L[0], 0, '+')
plt.axis('equal')
# Out:
# (0.64502013665094671,
#  1.1800535517113488,
#  -0.60712667112640284,
#  0.60713410919245336)

# %%
x = np.linspace(mu1/2, 1.5*mu1, 101)
#y = np.ones((101, ))*1
y = -np.ones((101, ))
atan1 = np.arctan2(y, x - mu1) 
atan = np.arctan2(arr[:,1], arr[:,0]-mu1) 
atan[atan < 0] += 2*np.pi

# %%
arr.shape, atan.shape
# Out:
# ((389, 6), (101,))

# %%
plt.scatter(arr[:,4], atan[:])
#plt.scatter(np.arange(atan.size), atan1)

# %%
iVarAlphaPi(0, [mu1, 1])
# Out:
# 0.7915105148627598

# %%
np.pi/2
# Out:
# 1.5707963267948966
